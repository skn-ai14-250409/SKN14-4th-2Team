# %%
from utils2.retreiver_setting import faiss_retriever_loading

accounting_retriever, business_retriever = faiss_retriever_loading()

# %%
business_retriever.invoke('2023년 삼성전자 사업보고')
# Out:
# [Document(metadata={'연도': 2023, '회사명': '삼성전자'}, page_content='분기보고서\n5.0\n삼성전자주식회사\n130111-0006246\n분 기 보 고 서\n(제 55 기)\n사업연도\n2023년 01월 01일\n부터\n2023년 03월 31일\n까지\n금융위원회\n한국거래소 귀중\n2023년 5월 15일\n제출대상법인 유형 :\n주권상장법인\n면제사유발생 :\n해당사항 없음\n회 사 명 :\n삼성전자주식회사\n대 표 이 사 :\n한 종 희\n본 점 소 재 지 :\n경기도 수원시 영통구 삼성로 129(매탄동)\n(전 화) 031-200-1114\n(홈페이지) http://www.samsung.com/sec\n작 성 책 임 자 :\n(직 책) 재경팀장 (성 명) 김 동 욱\n(전 화) 031-277-7218\n목 차\n【 대표이사 등의 확인 】\n---------------------------------\n1\nI. 회사의 개요\n---------------------------------\n2\n1. 회사의 개요\n---------------------------------\n2\n2. 회사의 연혁\n---------------------------------\n2\n3. 자본금 변동사항\n---------------------------------\n2\n4. 주식의 총수 등\n---------------------------------\n2\n5. 정관에 관한 사항\n---------------------------------\n2\nII. 사업의 내용\n---------------------------------\n3\n1. 사업의 개요\n---------------------------------\n3\n2. 주요 제품 및 서비스\n---------------------------------\n5\n3. 원재료 및 생산설비\n---------------------------------\n6\n4. 매출 및 
# ...

# %% [markdown]
# ## 답변 내용 체크

# %%
from utils2.graph_setting import graph_setting

graph = graph_setting()

# %%
graph

# %%
from utils2.main import run_langraph

# %%
run_langraph('2024년 삼성전자 재무제표 알려줘', 'id_1', level='basic')
# Out:
# {'question': '2024년 삼성전자 재무제표 알려줘',
#  'company': '삼성전자',
#  'year': ['2024'],
#  'route': 'finance',
#  'level': 'basic',
#  'answer': '안녕하세요! 삼성전자의 2024년 성적표를 쉽고 간단하게 알려드릴게요.\n\n**✅ 돈은 작년보다 잘 벌었나요?**\n네, 아주 잘 벌었어요!\n- **매출** (회사의 1년 총 판매금액)은 **16.2% 늘어난 3,008,709억원**을 기록했고요,\n- **영업이익** (장사해서 실제로 남긴 돈)은 무려 **398.3%나 늘어난 32,726억원**이에요. 작년보다 장사를 훨씬 잘했네요!\n\n**✅ 회사는 튼튼한가요?**\n네, 튼튼해요!\n- **자산** (회사가 가진 모든 재산)은 **12.9% 늘어난 5,145,319억원**이고요,\n- **부채** (갚아야 할 돈)는 **92,228억원**에서 **112,340억원**으로 조금 늘었지만, 자산에 비하면 아주 적은 수준이에요.\n\n**한마디로,** 삼성전자는 2024년에 돈도 훨씬 잘 벌고 회사도 더 튼튼해졌어요!\n\n더 궁금한 점 있으시면 편하게 물어보세요.',
#  'chat_history': [{'role': 'user', 'content': '2024년 삼성전자 재무제표 알려줘'},
#   {'role': 'assistant',
# ...

# %%
run_langraph('LG전자 사업은 어떄?', 'id_1', level='intermediate')
# Out:
# C:\Workspaces\my2\JeongMinYoung\utils2\graph_node.py:255: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = business_retriever.get_relevant_documents(question)
# {'question': 'LG전자 사업은 어떄?',
#  'company': 'LG전자',
#  'year': ['2023', '2024'],
#  'route': 'business',
#  'level': 'intermediate',
# ...

# %%
run_langraph('재고자산 처리방법이 머야?', 'id_1')
# Out:
# {'question': '재고자산 처리방법이 머야?',
#  'company': 'LG전자',
#  'year': ['2023', '2024'],
#  'route': 'accounting',
#  'level': 'basic',
#  'answer': "안녕하세요! 재고자산 처리방법이 궁금하시군요. 아주 쉽게 설명해드릴게요.\n\n**한마디로 말하면,** 재고자산 처리방법은 재고의 가치를 어떻게 계산하고 기록할지를 정하는 방법이에요.\n\n예를 들어, 가게에서 물건을 팔 때 어떤 물건이 먼저 팔렸는지에 따라 계산하는 방법이 달라질 수 있어요. '선입선출법'은 먼저 들어온 물건이 먼저 팔린다고 가정하는 방법이고, '가중평균법'은 모든 물건의 평균 가격을 계산해서 사용하는 방법이에요. 이렇게 하면 재고의 가치를 정확하게 알 수 있어요.\n\n더 궁금한 점 있으시면 편하게 물어보세요!",
#  'chat_history': [{'role': 'user', 'content': '2024년 삼성전자 재무제표 알려줘'},
#   {'role': 'assistant',
# ...

# %%
run_langraph('삼성전자 2024년 사업보고서', 'id_1')
# Out:
# C:\Workspaces\JeongMinYoung\utils2\graph_node.py:138: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = self_retriever.get_relevant_documents(question)
# '"안녕하세요! 삼성전자 2024년 사업보고서에 대해 가장 중요한 것만 알려드릴게요.\n\n**이 회사는요,** TV, 스마트폰, 반도체 같은 전자제품을 만드는 곳이에요.\n\n**가장 큰 이슈는** 연구개발에 많은 투자를 하고 있다는 점이에요. 매출의 8.5%를 연구개발에 쓰고 있고, 특히 차세대 반도체와 인공지능 기술에 집중하고 있어요.\n\n더 궁금한 게 생기면 언제든 다시 물어보세요!"'

# %%
run_langraph('내가 방금 뭐 물어봤어?', 'id_1')
# Out:
# '당신은 방금 "삼성전자 2024년 사업보고서"에 대해 물어보셨습니다.'

# %%
run_langraph('내가 방금 뭐 물어봤어?', 'id_2')
# Out:
# '최근 대화 기록이 없어 방금 어떤 질문을 하셨는지 알 수 없습니다. 다른 질문이 있으시면 말씀해 주세요!'
